# %% [markdown]
# # A DeepXDE Implementation (PyTorch Backend) Into Option Pricing
# James Watson | University of Sussex | August 2025
#
# ---------------

# %% [markdown]
# # Sections
#
# ## 1. Black-Scholes (European Call Options)
#    ### 1.1 Single-Asset
#
#    >1.1.1 Initial Configuration
#    >
#    >1.1.2 Error Analysis
#    >
#    >1.1.3 Modified Configuration: LR Scheduling, RAR Sampling, Extensive Network
#    >
#    >1.1.4 Error Analysis
#    >
#    >1.1.5 Modified Configuration: LR Scheduling, RAR Sampling, Extensive Network, Adaptive Activation Functions
#    >
#    >1.1.6 Error Analysis
#    >
#
#    ### 1.2 10-Asset Basket Option
#
#    >1.2.1 Initial Configuration
#    >
#    >1.2.2 Modified Configuration: RAR Sampling
#    >
#
# ## 2. Heston (Single-Asset European Call Options)
#
#    >2.1 Initial Configuration
#    >
#    >2.2 Error Analysis
#    >
#    >2.3 Modified Configuration: SiLU Activation, LR Scheduling, IC Loss Function Weighting, Input Normalization
#    >
#    >2.4 Error Analysis
#    >
#    >2.5 Strike Error Analysis at $V=0$
#    >
#    >2.6 Modified Configuration: SiLU Activation, LR Scheduling, IC Loss Function Weighting, Input Normalization, RAR Sampling
#    >
#    >2.7 Error Analysis
#    >
# ---

# %% [markdown]
# # 🔒 PROPRIETARY CODE - CONFIDENTIAL
#
# **Access to full code** is restricted due to intellectual property considerations.
#
# **For code access requests or technical discussion:**
# 📧 **Contact:** [jameswatson.business@outlook.com](mailto:jameswatson.business@outlook.com)

# %% [markdown]
# ---
